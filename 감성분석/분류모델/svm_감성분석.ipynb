# %% [markdown]
# ### 데이터 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filepath =  '/content/drive/MyDrive/Colab/file/total_review_all_tokens.csv'

# %%
import io
import pandas as pd

# %%
df = pd.read_csv(filepath)

# %%
df
# Out:
#                                            product_name  rating skin_type  \
# 0      [증량]닥터지 레드 블레미쉬 클리어 수딩크림 기획 (본품70ml+30ml 추가 증정)        5       복합성
# 1      [증량]닥터지 레드 블레미쉬 클리어 수딩크림 기획 (본품70ml+30ml 추가 증정)        5       복합성
# 2      [증량]닥터지 레드 블레미쉬 클리어 수딩크림 기획 (본품70ml+30ml 추가 증정)        5       복합성
# 3      [증량]닥터지 레드 블레미쉬 클리어 수딩크림 기획 (본품70ml+30ml 추가 증정)        5        지성
# 4      [증량]닥터지 레드 블레미쉬 클리어 수딩크림 기획 (본품70ml+30ml 추가 증정)        5       복합성
# ...                                                 ...     ...       ...
# 92460                        밀크터치 서양송악 진정크림+송악점보패드(60매)       5      None
# 92461                        밀크터치 서양송악 진정크림+송악점보패드(60매)       5      None
# 92462                        밀크터치 서양송악 진정크림+송악점보패드(60매)       5      None
# 92463                        밀크터치 서양송악 진정크림+송악점보패드(60매)       5      None
# 92464                        밀크터치 서양송악 진정크림+송악점보패드(60매)       5      None
#
#                                                   review  \
# 0           제품은 정말 사용해보시라고 추천드리고싶어요진짜 좋은 제품이거든요사춘기때 여...
# 1         간단정리            자극없이 무난함  봄여름가을에 적당한 수분감  겨...
# 2        나의 피부상태  복합성 트러블 조금만 자극적이면 피부 뒤집어짐  장점   여드름...
# 3      또 샀어요     진짜 닥터지 최고입니다   건성분들이 쓰시기에는 너무 빨리 날아가...
# 4      닥터지 크림은 워낙 유명하기도 하고 성분이 순하고 진정효과가 좋아서 꾸준히 구매해왔...
# ...                                                  ...
# 92460                  최애 입니다이제 이것만 쓸거예요또사러 가야지 눈누난나 신난다
# 92461                자극이 없고 일단은 너무 촉촉해서 좋아요 이것만 쓰게 될것같아
# 92462      배송도 빠르고 세일할 때 사야할거 같아서 샀어요송악크림 건성한테 정말 좋을거같아요
# 92463             가벼운제형이고 끈적거리지 않아서 좋았어요  그리고 진정에도 좋습니다
# 92464              처음에 써보는 제품인데 의외로 괜찮아요  보습과 진정효과가 좋습니다
#
#                                                   tokens  label
# 0      ['제품', '은', '정말', '사용', '하', '아', '보', '시', '라...      1
# 1      ['간단', '정리', '자극', '없이', '무난', '하', 'ㅁ', '봄여름'...      1
# 2      ['나', '의', '피부', '상태', '복합성', '트러블', '조금', '만'...      1
# 3      ['또', '사', '았', '어요', '진짜', '닥터', '지', '최고', '...      1
# 4      ['닥터', '지', '크림', '은', '워낙', '유명', '하', '기', '...      1
# ...                                                  ...    ...
# 92460  ['최', '애', '입', '니다', '이제', '이것', '만', '쓰', 'ㄹ...      1
# 92461  ['자극', '이', '없', '고', '일단', '은', '너무', '촉촉', '...      1
# 92462  ['배송', '도', '빠르', '고', '세일', '하', 'ㄹ', '때', '사...      1
# 92463  ['가볍', 'ㄴ', '제', '형', '이', '고', '끈적거리', '지', '...      1
# 92464  ['처음', '에', '쓰', '어', '보', '는', '제품', '이', 'ㄴ데...      1
#
# [92465 rows x 6 columns]

# %%
df_=df.loc[df['label']!=-1] #별점값이 4였던 값들 제외

# %%
df_=df_.loc[df['skin_type']=='None'] #NoneType만

# %%
df_
# Out:
#                                            product_name  rating skin_type  \
# 69     [증량]닥터지 레드 블레미쉬 클리어 수딩크림 기획 (본품70ml+30ml 추가 증정)        3      None
# 70     [증량]닥터지 레드 블레미쉬 클리어 수딩크림 기획 (본품70ml+30ml 추가 증정)        5      None
# 88     [증량]닥터지 레드 블레미쉬 클리어 수딩크림 기획 (본품70ml+30ml 추가 증정)        5      None
# 113    [증량]닥터지 레드 블레미쉬 클리어 수딩크림 기획 (본품70ml+30ml 추가 증정)        5      None
# 120    [증량]닥터지 레드 블레미쉬 클리어 수딩크림 기획 (본품70ml+30ml 추가 증정)        3      None
# ...                                                 ...     ...       ...
# 92460                        밀크터치 서양송악 진정크림+송악점보패드(60매)       5      None
# 92461                        밀크터치 서양송악 진정크림+송악점보패드(60매)       5      None
# 92462                        밀크터치 서양송악 진정크림+송악점보패드(60매)       5      None
# 92463                        밀크터치 서양송악 진정크림+송악점보패드(60매)       5      None
# 92464                        밀크터치 서양송악 진정크림+송악점보패드(60매)       5      None
#
#                                                   review  \
# 69     제가 방금 올리브영에서 사와서 사용해봤는데요 닥터지 레드블레미쉬 수분크림은 목욕탕에...
# 70      닥터지 레드 블레미쉬 클리어 수딩 수분 크림 민감 피부 촉촉하게 잠재우다 저자극 ...
# 88       피부 유형  저는 민감성 피부입니다  군 복무 시절 냉동식품을 조금만 먹어도 여...
# 113     장점 년정도 쓰면서 이제 이제품이 없으면 안될정도로 여드름 지성피부 대표적인 크림...
# 120    저는 여드름이 나는 민감한 피부이고 수분이 부족한 복합성 피부입니다  요즘 얼굴에 ...
# ...                                                  ...
# 92460                  최애 입니다이제 이것만 쓸거예요또사러 가야지 눈누난나 신난다
# 92461                자극이 없고 일단은 너무 촉촉해서 좋아요 이것만 쓰게 될것같아
# 92462      배송도 빠르고 세일할 때 사야할거 같아서 샀어요송악크림 건성한테 정말 좋을거같아요
# 92463             가벼운제형이고 끈적거리지 않아서 좋았어요  그리고 진정에도 좋습니다
# 92464              처음에 써보는 제품인데 의외로 괜찮아요  보습과 진정효과가 좋습니다
#
#                                                   tokens  label
# 69     ['제가', '방금', '올리브', '영', '에서', '사와', '서', '사용'...      0
# 70     ['닥터', '지', '레드', '크', 'ㄹ', '리어', '수', '딩', '수...      1
# 88     ['피부', '유형', '저', '는', '민감성', '피부', '이', 'ㅂ니다'...      1
# 113    ['장점', '년', '정도', '쓰', '면서', '이제', '이', '제품', ...      1
# 120    ['저', '는', '여드름', '이', '나', '는', '민감', '하', 'ㄴ...      0
# ...                                                  ...    ...
# 92460  ['최', '애', '입', '니다', '이제', '이것', '만', '쓰', 'ㄹ...      1
# 92461  ['자극', '이', '없', '고', '일단', '은', '너무', '촉촉', '...      1
# 92462  ['배송', '도', '빠르', '고', '세일', '하', 'ㄹ', '때', '사...      1
# 92463  ['가볍', 'ㄴ', '제', '형', '이', '고', '끈적거리', '지', '...      1
# 92464  ['처음', '에', '쓰', '어', '보', '는', '제품', '이', 'ㄴ데...      1
#
# [58031 rows x 6 columns]

# %%
df_=df_.reset_index(drop=True)

# %%
df_['label'].value_counts()
# Out:
# 1    54089
# 0     3942
# Name: label, dtype: int64

# %%
df_ = df_.loc[:,["tokens","label"]]

# %%
from ast import literal_eval

# %%
df_['tokens'] = df_['tokens'].apply(literal_eval)

# %% [markdown]
# ### TF-IDF

# %%
from gensim import corpora, models

# %%
below = len(df_)//100

# %%
dictionary = corpora.Dictionary(df_['tokens'])
dictionary.filter_extremes(no_below=below)
bow_corpus = [dictionary.doc2bow(text) for text in df_['tokens']]
        
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]

# %%
len_dic = len(dictionary)
data_size = len(corpus_tfidf)

print(len_dic, data_size)
# Out:
# 692 58031

# %%
feature_list = [[0]*len_dic for i in range(data_size)] #len(dictionary)*len(data)

# %%
for i in range(data_size):
    for j in corpus_tfidf[i]:
        feature_list[i][j[0]] = j[1]

# %%
label = df_['label'].values.tolist()

# %%
import joblib

# %%
joblib.dump(dictionary, '/content/drive/MyDrive/Colab/file/None_token_dictionary.pkl')
# Out:
# ['/content/drive/MyDrive/Colab/file/None_token_dictionary.pkl']

# %% [markdown]
# ### UnderSampling

# %%
pip install -U imbalanced-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.9.1-py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 5.5 MB/s
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.4.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.21.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.1.0)
#   Downloading imbalanced_learn-0.9.0-py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 36.8 MB/s
# Requirement already satisfied: scikit-learn>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.0.2)
# Installing collected packages: imbalanced-learn
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.8.1
#     Uninstalling imbalanced-learn-0.8.1:
#       Successfully uninstalled imbalanced-learn-0.8.1
# Successfully installed imbalanced-learn-0.9.0

# %%
from imblearn.under_sampling import RandomUnderSampler
from imblearn.under_sampling import NearMiss

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(feature_list, label, test_size=0.3, random_state=123)

# %%
from collections import Counter

# %%
undersample = RandomUnderSampler(sampling_strategy='majority',random_state=0 )
under_X, under_y = undersample.fit_resample(X_train, y_train)

print(Counter(y_train))
print(Counter(under_y))
# Out:
# Counter({1: 37897, 0: 2724})
# Counter({0: 2724, 1: 2724})

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedKFold
from sklearn.svm import SVC

# %%
clf = SVC(kernel='rbf',random_state=42)
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

# define grid
param_grid = {"C":[0.01, 0.1, 1, 10, 100], 'gamma': [10, 1, 0.1, 0.01, 0.001]}
# define search
grid_search = GridSearchCV(clf, param_grid, cv=cv, n_jobs=-1, scoring='f1')
# perform the search
results = grid_search.fit(under_X, under_y)

# summarize
print('best_score: %.3f' % results.best_score_)
print('Config: %s' % results.best_params_)
# Out:
# best_score: 0.793
# Config: {'C': 1, 'gamma': 0.1}

# %%
import joblib
joblib.dump(results.best_estimator_, '/content/drive/MyDrive/Colab/file/None_svm_alltoken_model.pkl')
# Out:
# ['/content/drive/MyDrive/Colab/file/None_svm_alltoken_model.pkl']

# %% [markdown]
# ### best_estimator_불러오기

# %%
import joblib

# %%
loaded_model = joblib.load('/content/drive/MyDrive/Colab/file/None_svm_alltoken_model.pkl')

# %% [markdown]
# ### 성능평가

# %%
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, confusion_matrix, f1_score, classification_report

# %%
print('model.intercept_:',loaded_model.intercept_)

pred_y = loaded_model.predict(X_test)
print('r2_score: ',r2_score(y_test,pred_y))
print('mse: ', mean_squared_error(y_test,pred_y))
print('accuracy: ', accuracy_score(y_test, pred_y))
print('f1: ', f1_score(y_test, pred_y))
# Out:
# model.intercept_: [0.3571069]
# r2_score:  -2.1470998469920883
# mse:  0.20476737507179782
# accuracy:  0.7952326249282022
# f1:  0.8788774504807528

# %%
target_names = ['class 0', 'class 1']
print(classification_report(y_test, pred_y, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.22      0.75      0.34      1218
#      class 1       0.98      0.80      0.88     16192
#
#     accuracy                           0.80     17410
#    macro avg       0.60      0.77      0.61     17410
# weighted avg       0.92      0.80      0.84     17410

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tr_pred_y = loaded_model.predict(under_X)
cm_tr = confusion_matrix(under_y,tr_pred_y)

# %%
sns.heatmap(cm_tr, annot=True, annot_kws={"size": 20}, cmap='YlOrBr',fmt='d')
plt.xlabel('Predicted', fontsize=20)
plt.ylabel('Actual', fontsize=20)
# Out:
# Text(33.0, 0.5, 'Actual')

# %%
cm_te = confusion_matrix(y_test, pred_y)

# %%
sns.heatmap(cm_te, annot=True, annot_kws={"size": 20}, cmap='YlOrBr',fmt='d')
plt.xlabel('Predicted', fontsize=20)
plt.ylabel('Actual', fontsize=20)
# Out:
# Text(33.0, 0.5, 'Actual')

# %% [markdown]
# ### 단어 극성 확인

# %%
feature_zip = []

# %%
for idx, val in enumerate(loaded_model.coef_[0]):
#  (676, 1.3737868134050795),
#  (674, 1.406879968674751),
#  (117, 1.419438878277671),
#  (86, 1.4699085929966351),
#  (81, 1.4716808078164068),
#  (165, 1.4790086698032254),
#  (416, 1.509058070965522),
#  (539, 1.5171574844862286),
#  (55, 1.526849011875353),
#  (274, 1.6261648984111712),
#  (457, 1.63810661260753),
#  (26, 1.6960487574178555),
#  (244, 1.736887954811106),
#  (310, 1.7404190151977168),
#  (299, 1.7603288022953887),
#  (158, 1.780634354134962),
#  (74, 1.7825547265654653),
#  (25, 1.7863275975878348),
#  (554, 1.7869444175088247),
#  (175, 1.8070373172159218),
#  (500, 1.8154054318401467),
#  (176, 1.8206608649886569),
#  (157, 1.8381705895733205),
#  (453, 1.850965857933928),
#  (237, 1.8630885460058375),
#  (297, 1.9283906208736843),
#  (538, 1.9963222669455962),
#  (296, 2.0041154108132115),
#  (494, 2.054730558559751),
#  (222, 2.10835336627363),
#  (82, 2.481306482714336),
#  (347, 2.5703694091599836),
#  (202, 2.627606430919671),
#  (230, 3.0642077783410397),
#  (186, 3.2446022329924276)]

# %%
dict_sorted_li = []

# %%
for ft in feature_zip_sorted:
  dict_sorted_li.append((dictionary[ft[0]],ft[1]))

# %% [markdown]
# ##### 긍정

# %%
sorted(dict_sorted_li[-30:],key = lambda item: item[1],reverse=True)
# Out:
# [('만족', 3.2446022329924276),
#  ('딱', 3.0642077783410397),
#  ('쓰', 2.627606430919671),
#  ('진짜', 2.5703694091599836),
#  ('촉촉', 2.481306482714336),
#  ('강추', 2.10835336627363),
#  ('정착', 2.054730558559751),
#  ('없이', 2.0041154108132115),
#  ('짱', 1.9963222669455962),
#  ('에요', 1.9283906208736843),
#  ('순하', 1.8630885460058375),
#  ('최고', 1.850965857933928),
#  ('있', 1.8381705895733205),
#  ('확실히', 1.8206608649886569),
#  ('주름', 1.8154054318401467),
#  ('항상', 1.8070373172159218),
#  ('광', 1.7869444175088247),
#  ('되', 1.7863275975878348),
#  ('잘', 1.7825547265654653),
#  ('자', 1.780634354134962),
#  ('오래', 1.7603288022953887),
#  ('째', 1.7404190151977168),
#  ('정말', 1.736887954811106),
#  ('들', 1.6960487574178555),
#  ('환절기', 1.63810661260753),
#  ('이것', 1.6261648984111712),
#  ('아주', 1.526849011875353),
#  ('부담', 1.5171574844862286),
#  ('좋아하', 1.509058070965522),
#  ('좋아서', 1.4790086698032254)]

# %% [markdown]
# ##### 부정

# %%
dict_sorted_li[:30]
# Out:
# [('안', -4.081971765796337),
#  ('모르', -3.803116896690589),
#  ('별로', -3.4746170878907208),
#  ('못하', -3.4316511283662257),
#  ('아쉽', -3.2759309468866142),
#  ('그냥', -3.192596782233346),
#  ('아니', -2.360651135987763),
#  ('비', -2.3417730065115663),
#  ('저', -2.174635590883843),
#  ('올라오', -2.1331404363259643),
#  ('건지', -1.964548321555155),
#  ('밀리', -1.9550909681553874),
#  ('기', -1.9142696376956274),
#  ('어야', -1.8968246115112792),
#  ('기대', -1.8059905821672257),
#  ('하지만', -1.7509284793262423),
#  ('느낌', -1.734644908258668),
#  ('따갑', -1.7333051684980985),
#  ('좀', -1.7001152087886386),
#  ('은데', -1.697169897928906),
#  ('듯', -1.6904519894032155),
#  ('그런지', -1.597039090663544),
#  ('물', -1.5864765443537066),
#  ('좁쌀', -1.5803623027724998),
#  ('겠', -1.5639040800013522),
#  ('상품', -1.563302278372901),
#  ('부족', -1.5538314164773406),
#  ('무난', -1.5476135254317365),
#  ('음', -1.5174026916840468),
#  ('맞', -1.5162835615875419)]

# %%
coef_dict_df = pd.DataFrame(dict_sorted_li, columns = ['words','coef'])

# %%
coef_dict_df.to_csv('/content/drive/MyDrive/Colab/file/alltoken_coef_dict.csv',index = False, columns = ['words', 'coef'])

# %% [markdown]
# ### 문장단위 감성분류

# %%
test =  '/content/drive/MyDrive/Colab/file/total_test_tokens.csv'

# %%
test_sent = pd.read_csv(test)

# %%
test_sent['sen'] = test_sent['sen'].apply(literal_eval)

# %%
test_sent['sen'][294]
# Out:
# [('끈적이', 'VV'),
#  ('는', 'ETM'),
#  ('느낌', 'NNP'),
#  ('때문', 'NNB'),
#  ('에', 'JKB'),
#  ('피부', 'NNG'),
#  ('에', 'JKB'),
#  ('완전히', 'MAG'),
#  ('흡수', 'NNG'),
#  ('되', 'XSV'),
#  ('는', 'ETM'),
#  ('시간', 'NNG'),
#  ('은', 'JX'),
#  ('좀', 'MAG'),
#  ('더디', 'VA'),
#  ('ㄴ', 'ETM'),
#  ('편', 'NNB'),
#  ('이', 'VCP'),
#  ('에요', 'EC')]

# %%
test_token_list = [[token[0] for token in tokens ] for tokens in test_sent['sen']]

# %%
test_label = test_sent['pos_neg'].values.tolist()

# %%
test_corpus = [dictionary.doc2bow(text) for text in test_token_list]
tfidf = models.TfidfModel(bow_corpus)
test_tfidf = tfidf[test_corpus]

# %%
len_dic = len(dictionary)
data_size = len(test_tfidf)

print(len_dic, data_size)
# Out:
# 692 300

# %%
test_feature_list = [[0]*len_dic for i in range(data_size)] #len(dictionary)*len(data)

# %%
for i in range(data_size):
    for j in test_tfidf[i]:
        test_feature_list[i][j[0]] = j[1]

# %%
pred_sent_y = loaded_model.predict(test_feature_list)

# %%
cm = confusion_matrix(test_label, pred_sent_y)

# %%
sns.heatmap(cm, annot=True, annot_kws={"size": 20}, cmap='YlOrBr',fmt='d')
plt.xlabel('Predicted', fontsize=20)
plt.ylabel('Actual', fontsize=20)
# Out:
# Text(33.0, 0.5, 'Actual')

# %%
print('accuracy: ', accuracy_score(test_label, pred_sent_y))
print('f1: ', f1_score(test_label, pred_sent_y))
# Out:
# accuracy:  0.7966666666666666
# f1:  0.8087774294670846

# %% [markdown]
# ### 문장별로 확인

# %%
score = float(loaded_model.predict(test_feature_list[299:300]))

if(score > 0.5):
  print(" 긍정 리뷰입니다.")
else:
  print("부정 리뷰입니다")
# Out:
# 부정 리뷰입니다
